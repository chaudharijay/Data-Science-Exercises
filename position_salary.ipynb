# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('position_salary.csv', encoding='latin-1')
df
# Out:
#                                Position   Location  Gender    Education  \
# 0     QNXT Configuration QA/Testing SME  Ghaziabad  Female  B.Tech/B.E.
# 1              Provider Data Management  New Delhi  Female  B.Tech/B.E.
# 2             Accessibility Engineer QA      Noida  Female          BCA
# 3              Senior Software Engineer  Jalandhar    Male          NaN
# 4            Java Developer/Spring Boot     Meerut    Male          B.A
# ...                                 ...        ...     ...          ...
# 3462               Salesforce developer  Hyderabad    Male  B.Tech/B.E.
# 3463               Salesforce developer  Bengaluru    Male          BCA
# 3464               Salesforce developer  New Delhi  Female          NaN
# 3465               Salesforce developer   Gurugram    Male          B.A
# 3466               Salesforce developer       Pune    Male        B.Com
#
#       Experience (Years)   Salary
# 0                     11  2014510
# ...

# %%
df.head()
# Out:
#                             Position   Location  Gender    Education  \
# 0  QNXT Configuration QA/Testing SME  Ghaziabad  Female  B.Tech/B.E.
# 1           Provider Data Management  New Delhi  Female  B.Tech/B.E.
# 2          Accessibility Engineer QA      Noida  Female          BCA
# 3           Senior Software Engineer  Jalandhar    Male          NaN
# 4         Java Developer/Spring Boot     Meerut    Male          B.A
#
#    Experience (Years)   Salary
# 0                  11  2014510
# 1                  24  1624349
# 2                  25  1926223
# 3                  27  2403560
# 4                  11  1128404

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3467 entries, 0 to 3466
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Position            3448 non-null   object
#  1   Location            3467 non-null   object
#  2   Gender              3443 non-null   object
#  3   Education           3391 non-null   object
#  4   Experience (Years)  3467 non-null   int64
#  5   Salary              3467 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 162.6+ KB

# %%
df.describe()
# Out:
#        Experience (Years)        Salary
# count         3467.000000  3.467000e+03
# mean            16.639746  1.487459e+06
# std              6.935259  5.776934e+05
# min              5.000000  5.026890e+05
# 25%             11.000000  9.818155e+05
# 50%             17.000000  1.475343e+06
# 75%             23.000000  1.985568e+06
# max             28.000000  2.499925e+06

# %%
df['Position'].unique()
# Out:
# array(['QNXT Configuration QA/Testing SME', 'Provider Data Management',
#        'Accessibility Engineer QA', 'Senior Software Engineer',
#        'Java Developer/Spring Boot', 'iOS Tester', 'GCP Cloud Architect',
#        'Technical Project Manager Remote', 'Provider Data Setup',
#        'Technical Lead(Data ADF)', 'System Engineer',
#        'Sr. Tableau or Power BI Developer', 'Android Tester',
#        'Sr. Data Ingestion/Analytics Engineer',
#        '\xa0Product Technical Specialist', 'Data Architect',
#        'QA Tester /Selenium', 'Cloud Architect', 'DevOps Eng',
#        'Tapestry Manager of Configuration', 'QNXT Configuration SME',
#        'Sr. software engineer/.Net,Azure', 'Facets SME',
#        'Senior Business Analyst', 'Claims SME',
#        'Senior Data Program Manager', 'IAM Architect', 'Senior Analyst',
#        'Senior Software Engineer/.Net', 'Sr. Data Platform Engineer',
#        'QNXT technical role', 'Tapestry Provider Analyst', 'FHIR SME',
# ...

# %%
# check for na value
df.isna().sum()
# Out:
# Position              19
# Location               0
# Gender                24
# Education             76
# Experience (Years)     0
# Salary                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Position              0
# Location              0
# Gender                0
# Education             0
# Experience (Years)    0
# Salary                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns

# %%
for col in df:
    sns.histplot(x=col,data=df,kde=True)
    plt.show()
# Out:
# C:\Users\Jay\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 150 (\x96) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
